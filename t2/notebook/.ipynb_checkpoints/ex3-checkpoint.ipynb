# %%
# This makes plots appear in the notebook
# %matplotlib inline 

import math
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage 

import siamxt

# %%
original_img = cv2.imread('../EP2/knee.pgm', cv2.IMREAD_GRAYSCALE)
print(original_img.max())
original_img = original_img.astype(np.uint16)

fig, imgs = plt.subplots(1,1, figsize=(15,15))
imgs.imshow(original_img, cmap='gray')
plt.title('Original')
plt.show()
# Out:
# 240

# %%
# Rounded Structuring Element
struct = ndimage.generate_binary_structure(2, 1)

dilation = ndimage.grey_dilation(original_img, structure=struct)
erosion = ndimage.grey_erosion(original_img, structure=struct)

gradient_img = dilation - erosion

fig, imgs = plt.subplots(1,1, figsize=(15,15))
imgs.imshow(gradient_img, cmap='gray')
plt.title('Original')
plt.show()

# %%
# Neighborhood connectivity-8
neighborhood = np.ones((3,3),dtype = bool)

# Number of leaves to be preserved
n = 8

mxt_gradient = siamxt.MaxTreeAlpha(gradient_img, neighborhood)


# TODO: trocar para volume
# Select the area attribute of the max-tree nodes from NA
area = mxt_gradient.node_array[3,:]
height = mxt_gradient.computeHeight()

volume = area * height

# Computes the area extinction values
area_ext = mxt_gradient.computeExtinctionValues(volume,"volume")

# Applies the  area extinction filter
mxt_gradient.extinctionFilter(area_ext,n)

#Recovering the image 
img_gradient_filtered =  mxt_gradient.getImage()


#Displaying the filtered image
fig, imgs = plt.subplots(1,1, figsize=(15,15))
imgs.imshow(img_gradient_filtered, cmap='Greys_r')
plt.axis('off')
plt.title("area extinction filter, n= %d " %n)
# Out:
# Text(0.5,1,u'area extinction filter, n= 8 ')

# %%
# Negating the image
max_gradient = img_gradient_filtered.max()
img_gradient_filtered_neg = max_gradient - img_gradient_filtered

mxt_neg = siamxt.MaxTreeAlpha(img_gradient_filtered_neg, neighborhood)

#Selecting nodes that fit the criteria
nodes = mxt_neg.node_array[1,:] == 0

print len(nodes)

#Filtering
mxt_neg.contractDR(nodes)

img_filtered = mxt_neg.getImage()

img_map = np.where(img_filtered > 0,1,0)

#Displaying the filtered image
fig, imgs = plt.subplots(1,1, figsize=(10,10))
imgs.imshow(img_map, cmap='Greys_r')
plt.axis('off')
# Out:
# 2420
# (-0.5, 170.5, 192.5, -0.5)

# %%
# Marker labelling
ret, markers = cv2.connectedComponents(img_map)

# Add one to all labels so that sure background is not 0, but 1
markers = markers+1

# Now, mark the region of unknown with zero
markers[unknown==255] = 0

markers = cv2.watershed(gradient_img, markers)

img[markers == -1] = [255,0,0]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-28-9025d95b86d5> in <module>()
#       1 # Marker labelling
# ----> 2 ret, markers = cv2.connectedComponents(img_map)
#       3
#       4 # Add one to all labels so that sure background is not 0, but 1
#       5 markers = markers+1
#
# error: OpenCV(3.4.1) /feedstock_root/build_artefacts/opencv_1520722613778/work/opencv-3.4.1/modules/imgproc/src/connectedcomponents.cpp:3941: error: (-215) iDepth == 0 || iDepth == 1 in function connectedComponents_sub1
